# %%
import sklearn
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# Seed para que las redes con iguales parametros no generen resultados aleatorios y tener repetibilidad
np.random.seed(42)
tf.random.set_seed(42)

# Para las graficas importamos matplotlib
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

#Función para plotear
def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")

#Función Rounded Accuracy
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

    
#Traemos los datos de Fashion MNIST
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full_normalized = X_train_full.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255
X_train, X_valid = X_train_full_normalized[:-5000], X_train_full_normalized[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

#Función para ver los resultados de las reconstrucciones
def show_reconstructions(model, images=X_test, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])
        
#Función para ver los resultados de las reconstrucciones en el modelo con 2 salidas
def show_reconstructions_class(model, images=X_test, n_images=5):
    reconstructions,_ = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])
        
#Función para visualziar multiples imagenes generadas por las GANs o VAEs        
def plot_multiple_images(images, n_cols=None):
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)
    plt.figure(figsize=(n_cols, n_rows))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image, cmap="binary")
        plt.axis("off")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#definimos la operacion kernel

def rbf_kernel(X, Y, sigma=1.0):
    """
    Computes the RBF (Gaussian) kernel between two tensors X and Y.

    Args:
        X: Tensor of shape (batch_size, latent_dim)
        Y: Tensor of shape (batch_size, latent_dim)
        sigma: Bandwidth parameter for the RBF kernel

    Returns:
        Tensor of shape (batch_size, batch_size) representing the kernel matrix
    """
    X_expanded = tf.expand_dims(X, axis=1)  # Shape: (batch_size, 1, latent_dim)
    Y_expanded = tf.expand_dims(Y, axis=0)  # Shape: (1, batch_size, latent_dim)
    squared_distance = tf.reduce_sum(tf.square(X_expanded - Y_expanded), axis=2)
    return tf.exp(-squared_distance / (2 * sigma ** 2))

#definimos la operacion MMD
def compute_mmd(z, z_prior, kernel_fn):
    """
    Computes the Maximum Mean Discrepancy (MMD) between two distributions.

    Args:
        z: Tensor of shape (batch_size, latent_dim) from the encoder
        z_prior: Tensor of shape (batch_size, latent_dim) sampled from the prior
        kernel_fn: A function that computes the kernel between two sets of samples

    Returns:
        Scalar tensor representing the MMD loss
    """
    # Compute kernels
    K_zz = kernel_fn(z, z)
    K_zz_prior = kernel_fn(z, z_prior)
    K_prior_prior = kernel_fn(z_prior, z_prior)

    # Compute means
    mmd = tf.reduce_mean(K_zz) + tf.reduce_mean(K_prior_prior) - 2 * tf.reduce_mean(K_zz_prior)
    return mmd

# %%
#Definimos una funcion para crear el encoder con la API funcional
def build_encoder(latent_dim):
    encoder_inputs = tf.keras.layers.Input(shape=(28, 28, 1))
    x = keras.layers.RandomFlip(mode="horizontal")(encoder_inputs)#Usamos unas capas de random flip y random contrast para aumentar artificialmente los datos de entrada
    x = keras.layers.RandomContrast(factor=0.2)(x)
    x = tf.keras.layers.Conv2D(32, 3, activation='relu', strides=2, padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2D(64, 3, activation='relu', strides=2, padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = keras.layers.Dropout(0.5)(x)
    z_mean = tf.keras.layers.Dense(latent_dim)(x)
    z_log_var = tf.keras.layers.Dense(latent_dim)(x)
    encoder = tf.keras.Model(encoder_inputs, [z_mean, z_log_var], name='encoder')
    return encoder

#Definimos la función que crea el decoder con la API funcional
def build_decoder(latent_dim):
    decoder_inputs = tf.keras.layers.Input(shape=(latent_dim,))
    x = tf.keras.layers.Dense(7*7*64, activation='relu')(decoder_inputs)
    x = tf.keras.layers.Reshape((7, 7, 64))(x)
    x = tf.keras.layers.Conv2DTranspose(64, 3, activation='relu', strides=2, padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Conv2DTranspose(32, 3, activation='relu', strides=2, padding='same')(x)
    x = keras.layers.BatchNormalization()(x)
    decoder_outputs = tf.keras.layers.Conv2DTranspose(1, 3, activation='sigmoid', padding='same')(x)
    decoder = tf.keras.Model(decoder_inputs, decoder_outputs, name='decoder')
    return decoder

#Esta clase se crea para introducir las propiedades del autoencode variacional, en particular el loss probabilistico
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder, alpha=0.01,sigma=1.0, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.alpha = alpha #Este parametro se usara para darle peso a la regularizacion con el loss KL
        self.sigma = sigma  # Kernel bandwidth
        
#La funcion call de la clase VAE calcula el loss por divergencia Kl usando los datos de salida del encoder, y luego los añade
#usado el metrodo add_loss
    def call(self, inputs):
        z_mean, z_log_var = self.encoder(inputs)
        z = self.reparameterize(z_mean, z_log_var)
        reconstructed = self.decoder(z)
        z_prior = tf.random.normal(shape=tf.shape(z))
        mmd_loss = compute_mmd(z, z_prior, lambda x, y: rbf_kernel(x, y, sigma=self.sigma))
        #kl_loss = self.alpha * -0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
        #self.add_loss(kl_loss)
        self.add_loss(mmd_loss)
        return reconstructed
    
#Esta funcion se usa en la función call para convertir las muestras del espacio latente en un conjunto continuo y diferenciable, y asi 
#el espacio latente se convierte en la nube de probabilidad
    def reparameterize(self, z_mean, z_log_var):
        eps = tf.random.normal(shape=tf.shape(z_mean))
        return eps * tf.exp(z_log_var * .5) + z_mean

#Para poder usar el parametro de escalado y darle pesos a los diferentes loss creamos una clase para un loss custom escalado
class ScaledBinaryCrossentropy:
    #la funcion init para inicializar el factor de escalada
    def __init__(self, scale=1.0):
        self.scale = scale
        
    #En la funcion call se calcula la perdida escalada y la retorna
    def __call__(self, y_true, y_pred):
        # Calcula la binary crossentropy
        bce = tf.keras.backend.binary_crossentropy(y_true, y_pred)
        # Retorna la binary crossentropy escalada
        return self.scale * bce

# %%
#Luego de definir las funcions y la clase VAE, se crea y compila  el modelo
#Este parametro determina el tamaño del espacio latente, o lo que es lo mismo, el número de neuronas de las últimas capas del encoder
latent_dim = 8
#Llamamos las funciones para crear el encoder y decoder
encoder = build_encoder(latent_dim)
decoder = build_decoder(latent_dim)
#Definimos los pesos que llevaran los loss
alpha = 0.6
beta= 1-alpha
#Usamos la clase VAE para definir el modelo
vae = VAE(encoder, decoder,alpha)
#Se crea el callback para el learning rate scheduling
#piecewise_constant_fn = piecewise_constant([100,200,300], [0.1, 0.01, 0.005,0.001])
#scheduler=keras.callbacks.LearningRateScheduler(piecewise_constant_fn)

#Creamos el objeto loss que va a calcular la crossentropia escalada
loss2=ScaledBinaryCrossentropy(beta)
#Compilamos
vae.compile(optimizer=keras.optimizers.SGD(learning_rate=5e-1), loss=loss2,metrics=[rounded_accuracy])

# %%
#Clear session para no guardar datos de entrenamientos anteriores
keras.backend.clear_session()
history=vae.fit(X_train, X_train, epochs=200, batch_size=32, validation_data=(X_valid, X_valid))#,callbacks=[scheduler])
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726010319.417292     110 service.cc:145] XLA service 0x77fc640045c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1726010319.417369     110 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1726010319.417375     110 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   35/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.3228 - rounded_accuracy: 0.6548
# I0000 00:00:1726010327.808363     110 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 30s 11ms/step - loss: 0.2697 - rounded_accuracy: 0.7588 - val_loss: 0.2099 - val_rounded_accuracy: 0.8849
# Epoch 2/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1966 - rounded_accuracy: 0.9027 - val_loss: 0.2009 - val_rounded_accuracy: 0.8966
# Epoch 3/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1911 - rounded_accuracy: 0.9099 - val_loss: 0.1954 - val_rounded_accuracy: 0.9022
# Epoch 4/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1886 - rounded_accuracy: 0.9122 - val_loss: 0.1942 - val_rounded_accuracy: 0.9037
# Epoch 5/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1870 - rounded_accuracy: 0.9145 - val_loss: 0.1907 - val_rounded_accuracy: 0.9098
# Epoch 6/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1858 - rounded_accuracy: 0.9154 - val_loss: 0.1913 - val_rounded_accuracy: 0.9067
# Epoch 7/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1849 - rounded_accuracy: 0.9164 - val_loss: 0.1910 - val_rounded_accuracy: 0.9048
# Epoch 8/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1841 - rounded_accuracy: 0.9172 - val_loss: 0.1861 - val_rounded_accuracy: 0.9167
# Epoch 9/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1836 - rounded_accuracy: 0.9180 - val_loss: 0.1852 - val_rounded_accuracy: 0.9178
# Epoch 10/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1832 - rounded_accuracy: 0.9186 - val_loss: 0.1844 - val_rounded_accuracy: 0.9195
# Epoch 11/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1824 - rounded_accuracy: 0.9186 - val_loss: 0.1850 - val_rounded_accuracy: 0.9173
# Epoch 12/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1823 - rounded_accuracy: 0.9194 - val_loss: 0.1855 - val_rounded_accuracy: 0.9160
# Epoch 13/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1816 - rounded_accuracy: 0.9195 - val_loss: 0.1831 - val_rounded_accuracy: 0.9203
# Epoch 14/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1813 - rounded_accuracy: 0.9200 - val_loss: 0.1851 - val_rounded_accuracy: 0.9151
# Epoch 15/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1810 - rounded_accuracy: 0.9201 - val_loss: 0.1834 - val_rounded_accuracy: 0.9179
# Epoch 16/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1807 - rounded_accuracy: 0.9206 - val_loss: 0.1831 - val_rounded_accuracy: 0.9181
# Epoch 17/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1806 - rounded_accuracy: 0.9208 - val_loss: 0.1847 - val_rounded_accuracy: 0.9131
# Epoch 18/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1804 - rounded_accuracy: 0.9214 - val_loss: 0.1854 - val_rounded_accuracy: 0.9125
# Epoch 19/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1802 - rounded_accuracy: 0.9213 - val_loss: 0.1825 - val_rounded_accuracy: 0.9192
# Epoch 20/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1798 - rounded_accuracy: 0.9221 - val_loss: 0.1841 - val_rounded_accuracy: 0.9173
# Epoch 21/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1796 - rounded_accuracy: 0.9224 - val_loss: 0.1831 - val_rounded_accuracy: 0.9185
# Epoch 22/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1793 - rounded_accuracy: 0.9225 - val_loss: 0.1828 - val_rounded_accuracy: 0.9191
# Epoch 23/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1791 - rounded_accuracy: 0.9228 - val_loss: 0.1832 - val_rounded_accuracy: 0.9156
# Epoch 24/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1790 - rounded_accuracy: 0.9230 - val_loss: 0.1820 - val_rounded_accuracy: 0.9212
# Epoch 25/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1788 - rounded_accuracy: 0.9233 - val_loss: 0.1826 - val_rounded_accuracy: 0.9173
# Epoch 26/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1787 - rounded_accuracy: 0.9235 - val_loss: 0.1816 - val_rounded_accuracy: 0.9221
# Epoch 27/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1785 - rounded_accuracy: 0.9236 - val_loss: 0.1818 - val_rounded_accuracy: 0.9189
# Epoch 28/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1784 - rounded_accuracy: 0.9239 - val_loss: 0.1813 - val_rounded_accuracy: 0.9216
# Epoch 29/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1780 - rounded_accuracy: 0.9240 - val_loss: 0.1806 - val_rounded_accuracy: 0.9243
# Epoch 30/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1781 - rounded_accuracy: 0.9243 - val_loss: 0.1812 - val_rounded_accuracy: 0.9194
# Epoch 31/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1779 - rounded_accuracy: 0.9242 - val_loss: 0.1807 - val_rounded_accuracy: 0.9231
# Epoch 32/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1780 - rounded_accuracy: 0.9243 - val_loss: 0.1801 - val_rounded_accuracy: 0.9239
# Epoch 33/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1776 - rounded_accuracy: 0.9248 - val_loss: 0.1813 - val_rounded_accuracy: 0.9193
# Epoch 34/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1775 - rounded_accuracy: 0.9250 - val_loss: 0.1820 - val_rounded_accuracy: 0.9191
# Epoch 35/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1773 - rounded_accuracy: 0.9251 - val_loss: 0.1806 - val_rounded_accuracy: 0.9220
# Epoch 36/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1774 - rounded_accuracy: 0.9252 - val_loss: 0.1806 - val_rounded_accuracy: 0.9220
# Epoch 37/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1772 - rounded_accuracy: 0.9253 - val_loss: 0.1810 - val_rounded_accuracy: 0.9212
# Epoch 38/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1770 - rounded_accuracy: 0.9256 - val_loss: 0.1804 - val_rounded_accuracy: 0.9243
# Epoch 39/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1769 - rounded_accuracy: 0.9259 - val_loss: 0.1790 - val_rounded_accuracy: 0.9259
# Epoch 40/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1769 - rounded_accuracy: 0.9259 - val_loss: 0.1806 - val_rounded_accuracy: 0.9224
# Epoch 41/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1767 - rounded_accuracy: 0.9259 - val_loss: 0.1796 - val_rounded_accuracy: 0.9245
# Epoch 42/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1767 - rounded_accuracy: 0.9262 - val_loss: 0.1798 - val_rounded_accuracy: 0.9239
# Epoch 43/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1764 - rounded_accuracy: 0.9262 - val_loss: 0.1831 - val_rounded_accuracy: 0.9162
# Epoch 44/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1765 - rounded_accuracy: 0.9264 - val_loss: 0.1791 - val_rounded_accuracy: 0.9256
# Epoch 45/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1765 - rounded_accuracy: 0.9265 - val_loss: 0.1814 - val_rounded_accuracy: 0.9194
# Epoch 46/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1765 - rounded_accuracy: 0.9264 - val_loss: 0.1793 - val_rounded_accuracy: 0.9260
# Epoch 47/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1762 - rounded_accuracy: 0.9264 - val_loss: 0.1788 - val_rounded_accuracy: 0.9249
# Epoch 48/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1763 - rounded_accuracy: 0.9268 - val_loss: 0.1799 - val_rounded_accuracy: 0.9219
# Epoch 49/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1761 - rounded_accuracy: 0.9269 - val_loss: 0.1794 - val_rounded_accuracy: 0.9237
# Epoch 50/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1760 - rounded_accuracy: 0.9269 - val_loss: 0.1790 - val_rounded_accuracy: 0.9247
# Epoch 51/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1761 - rounded_accuracy: 0.9271 - val_loss: 0.1799 - val_rounded_accuracy: 0.9227
# Epoch 52/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1759 - rounded_accuracy: 0.9272 - val_loss: 0.1790 - val_rounded_accuracy: 0.9237
# Epoch 53/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1759 - rounded_accuracy: 0.9272 - val_loss: 0.1791 - val_rounded_accuracy: 0.9245
# Epoch 54/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1756 - rounded_accuracy: 0.9273 - val_loss: 0.1790 - val_rounded_accuracy: 0.9246
# Epoch 55/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1757 - rounded_accuracy: 0.9274 - val_loss: 0.1793 - val_rounded_accuracy: 0.9247
# Epoch 56/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1754 - rounded_accuracy: 0.9274 - val_loss: 0.1796 - val_rounded_accuracy: 0.9246
# Epoch 57/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1757 - rounded_accuracy: 0.9275 - val_loss: 0.1787 - val_rounded_accuracy: 0.9265
# Epoch 58/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1754 - rounded_accuracy: 0.9274 - val_loss: 0.1789 - val_rounded_accuracy: 0.9262
# Epoch 59/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1754 - rounded_accuracy: 0.9276 - val_loss: 0.1785 - val_rounded_accuracy: 0.9261
# Epoch 60/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1753 - rounded_accuracy: 0.9277 - val_loss: 0.1788 - val_rounded_accuracy: 0.9244
# Epoch 61/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1752 - rounded_accuracy: 0.9278 - val_loss: 0.1792 - val_rounded_accuracy: 0.9236
# Epoch 62/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1753 - rounded_accuracy: 0.9278 - val_loss: 0.1787 - val_rounded_accuracy: 0.9262
# Epoch 63/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1753 - rounded_accuracy: 0.9279 - val_loss: 0.1794 - val_rounded_accuracy: 0.9235
# Epoch 64/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1751 - rounded_accuracy: 0.9280 - val_loss: 0.1794 - val_rounded_accuracy: 0.9244
# Epoch 65/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1753 - rounded_accuracy: 0.9282 - val_loss: 0.1790 - val_rounded_accuracy: 0.9253
# Epoch 66/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1750 - rounded_accuracy: 0.9282 - val_loss: 0.1790 - val_rounded_accuracy: 0.9249
# Epoch 67/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1749 - rounded_accuracy: 0.9281 - val_loss: 0.1784 - val_rounded_accuracy: 0.9268
# Epoch 68/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1750 - rounded_accuracy: 0.9281 - val_loss: 0.1787 - val_rounded_accuracy: 0.9256
# Epoch 69/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1749 - rounded_accuracy: 0.9283 - val_loss: 0.1783 - val_rounded_accuracy: 0.9268
# Epoch 70/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1749 - rounded_accuracy: 0.9283 - val_loss: 0.1785 - val_rounded_accuracy: 0.9273
# Epoch 71/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1749 - rounded_accuracy: 0.9282 - val_loss: 0.1778 - val_rounded_accuracy: 0.9269
# Epoch 72/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1745 - rounded_accuracy: 0.9283 - val_loss: 0.1779 - val_rounded_accuracy: 0.9273
# Epoch 73/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1747 - rounded_accuracy: 0.9285 - val_loss: 0.1779 - val_rounded_accuracy: 0.9279
# Epoch 74/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1748 - rounded_accuracy: 0.9287 - val_loss: 0.1796 - val_rounded_accuracy: 0.9235
# Epoch 75/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1747 - rounded_accuracy: 0.9286 - val_loss: 0.1780 - val_rounded_accuracy: 0.9265
# Epoch 76/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1745 - rounded_accuracy: 0.9285 - val_loss: 0.1778 - val_rounded_accuracy: 0.9269
# Epoch 77/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1743 - rounded_accuracy: 0.9287 - val_loss: 0.1787 - val_rounded_accuracy: 0.9262
# Epoch 78/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1746 - rounded_accuracy: 0.9287 - val_loss: 0.1783 - val_rounded_accuracy: 0.9255
# Epoch 79/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1743 - rounded_accuracy: 0.9287 - val_loss: 0.1783 - val_rounded_accuracy: 0.9259
# Epoch 80/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1745 - rounded_accuracy: 0.9285 - val_loss: 0.1786 - val_rounded_accuracy: 0.9240
# Epoch 81/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1744 - rounded_accuracy: 0.9288 - val_loss: 0.1794 - val_rounded_accuracy: 0.9245
# Epoch 82/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1744 - rounded_accuracy: 0.9289 - val_loss: 0.1778 - val_rounded_accuracy: 0.9268
# Epoch 83/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1744 - rounded_accuracy: 0.9290 - val_loss: 0.1783 - val_rounded_accuracy: 0.9267
# Epoch 84/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1743 - rounded_accuracy: 0.9290 - val_loss: 0.1780 - val_rounded_accuracy: 0.9277
# Epoch 85/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1741 - rounded_accuracy: 0.9290 - val_loss: 0.1777 - val_rounded_accuracy: 0.9267
# Epoch 86/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1743 - rounded_accuracy: 0.9291 - val_loss: 0.1777 - val_rounded_accuracy: 0.9277
# Epoch 87/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1741 - rounded_accuracy: 0.9291 - val_loss: 0.1776 - val_rounded_accuracy: 0.9279
# Epoch 88/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1741 - rounded_accuracy: 0.9290 - val_loss: 0.1791 - val_rounded_accuracy: 0.9248
# Epoch 89/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1738 - rounded_accuracy: 0.9291 - val_loss: 0.1776 - val_rounded_accuracy: 0.9280
# Epoch 90/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1740 - rounded_accuracy: 0.9292 - val_loss: 0.1780 - val_rounded_accuracy: 0.9271
# Epoch 91/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1740 - rounded_accuracy: 0.9291 - val_loss: 0.1777 - val_rounded_accuracy: 0.9272
# Epoch 92/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1740 - rounded_accuracy: 0.9293 - val_loss: 0.1779 - val_rounded_accuracy: 0.9261
# Epoch 93/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1739 - rounded_accuracy: 0.9294 - val_loss: 0.1771 - val_rounded_accuracy: 0.9283
# Epoch 94/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1739 - rounded_accuracy: 0.9294 - val_loss: 0.1780 - val_rounded_accuracy: 0.9279
# Epoch 95/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1738 - rounded_accuracy: 0.9294 - val_loss: 0.1776 - val_rounded_accuracy: 0.9276
# Epoch 96/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1739 - rounded_accuracy: 0.9294 - val_loss: 0.1791 - val_rounded_accuracy: 0.9252
# Epoch 97/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1738 - rounded_accuracy: 0.9295 - val_loss: 0.1778 - val_rounded_accuracy: 0.9273
# Epoch 98/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1737 - rounded_accuracy: 0.9294 - val_loss: 0.1781 - val_rounded_accuracy: 0.9274
# Epoch 99/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1738 - rounded_accuracy: 0.9294 - val_loss: 0.1776 - val_rounded_accuracy: 0.9289
# Epoch 100/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1737 - rounded_accuracy: 0.9297 - val_loss: 0.1781 - val_rounded_accuracy: 0.9268
# Epoch 101/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1738 - rounded_accuracy: 0.9296 - val_loss: 0.1774 - val_rounded_accuracy: 0.9275
# Epoch 102/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1738 - rounded_accuracy: 0.9295 - val_loss: 0.1771 - val_rounded_accuracy: 0.9281
# Epoch 103/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1737 - rounded_accuracy: 0.9297 - val_loss: 0.1781 - val_rounded_accuracy: 0.9251
# Epoch 104/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1735 - rounded_accuracy: 0.9295 - val_loss: 0.1780 - val_rounded_accuracy: 0.9267
# Epoch 105/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1736 - rounded_accuracy: 0.9296 - val_loss: 0.1776 - val_rounded_accuracy: 0.9277
# Epoch 106/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1735 - rounded_accuracy: 0.9296 - val_loss: 0.1773 - val_rounded_accuracy: 0.9287
# Epoch 107/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1735 - rounded_accuracy: 0.9297 - val_loss: 0.1772 - val_rounded_accuracy: 0.9280
# Epoch 108/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1735 - rounded_accuracy: 0.9297 - val_loss: 0.1779 - val_rounded_accuracy: 0.9281
# Epoch 109/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1734 - rounded_accuracy: 0.9296 - val_loss: 0.1779 - val_rounded_accuracy: 0.9277
# Epoch 110/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1735 - rounded_accuracy: 0.9298 - val_loss: 0.1784 - val_rounded_accuracy: 0.9273
# Epoch 111/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1735 - rounded_accuracy: 0.9299 - val_loss: 0.1778 - val_rounded_accuracy: 0.9280
# Epoch 112/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1733 - rounded_accuracy: 0.9298 - val_loss: 0.1782 - val_rounded_accuracy: 0.9275
# Epoch 113/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1734 - rounded_accuracy: 0.9298 - val_loss: 0.1769 - val_rounded_accuracy: 0.9290
# Epoch 114/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1733 - rounded_accuracy: 0.9299 - val_loss: 0.1774 - val_rounded_accuracy: 0.9285
# Epoch 115/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1733 - rounded_accuracy: 0.9299 - val_loss: 0.1773 - val_rounded_accuracy: 0.9287
# Epoch 116/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1733 - rounded_accuracy: 0.9299 - val_loss: 0.1776 - val_rounded_accuracy: 0.9283
# Epoch 117/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1734 - rounded_accuracy: 0.9300 - val_loss: 0.1781 - val_rounded_accuracy: 0.9267
# Epoch 118/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1734 - rounded_accuracy: 0.9300 - val_loss: 0.1778 - val_rounded_accuracy: 0.9271
# Epoch 119/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1733 - rounded_accuracy: 0.9300 - val_loss: 0.1783 - val_rounded_accuracy: 0.9274
# Epoch 120/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1731 - rounded_accuracy: 0.9301 - val_loss: 0.1771 - val_rounded_accuracy: 0.9291
# Epoch 121/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1732 - rounded_accuracy: 0.9301 - val_loss: 0.1779 - val_rounded_accuracy: 0.9282
# Epoch 122/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1731 - rounded_accuracy: 0.9301 - val_loss: 0.1769 - val_rounded_accuracy: 0.9289
# Epoch 123/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1733 - rounded_accuracy: 0.9301 - val_loss: 0.1776 - val_rounded_accuracy: 0.9263
# Epoch 124/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1731 - rounded_accuracy: 0.9301 - val_loss: 0.1774 - val_rounded_accuracy: 0.9285
# Epoch 125/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1731 - rounded_accuracy: 0.9303 - val_loss: 0.1776 - val_rounded_accuracy: 0.9277
# Epoch 126/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1731 - rounded_accuracy: 0.9300 - val_loss: 0.1774 - val_rounded_accuracy: 0.9282
# Epoch 127/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1730 - rounded_accuracy: 0.9302 - val_loss: 0.1775 - val_rounded_accuracy: 0.9281
# Epoch 128/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1731 - rounded_accuracy: 0.9302 - val_loss: 0.1785 - val_rounded_accuracy: 0.9266
# Epoch 129/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1730 - rounded_accuracy: 0.9303 - val_loss: 0.1770 - val_rounded_accuracy: 0.9281
# Epoch 130/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1730 - rounded_accuracy: 0.9303 - val_loss: 0.1779 - val_rounded_accuracy: 0.9268
# Epoch 131/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1729 - rounded_accuracy: 0.9304 - val_loss: 0.1770 - val_rounded_accuracy: 0.9282
# Epoch 132/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1729 - rounded_accuracy: 0.9304 - val_loss: 0.1773 - val_rounded_accuracy: 0.9287
# Epoch 133/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1730 - rounded_accuracy: 0.9303 - val_loss: 0.1774 - val_rounded_accuracy: 0.9289
# Epoch 134/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1730 - rounded_accuracy: 0.9304 - val_loss: 0.1779 - val_rounded_accuracy: 0.9283
# Epoch 135/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1728 - rounded_accuracy: 0.9304 - val_loss: 0.1770 - val_rounded_accuracy: 0.9288
# Epoch 136/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1729 - rounded_accuracy: 0.9304 - val_loss: 0.1776 - val_rounded_accuracy: 0.9262
# Epoch 137/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1730 - rounded_accuracy: 0.9304 - val_loss: 0.1770 - val_rounded_accuracy: 0.9288
# Epoch 138/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1729 - rounded_accuracy: 0.9304 - val_loss: 0.1783 - val_rounded_accuracy: 0.9265
# Epoch 139/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1729 - rounded_accuracy: 0.9305 - val_loss: 0.1777 - val_rounded_accuracy: 0.9287
# Epoch 140/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1727 - rounded_accuracy: 0.9305 - val_loss: 0.1781 - val_rounded_accuracy: 0.9266
# Epoch 141/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1727 - rounded_accuracy: 0.9305 - val_loss: 0.1775 - val_rounded_accuracy: 0.9287
# Epoch 142/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1729 - rounded_accuracy: 0.9305 - val_loss: 0.1785 - val_rounded_accuracy: 0.9266
# Epoch 143/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1728 - rounded_accuracy: 0.9304 - val_loss: 0.1775 - val_rounded_accuracy: 0.9281
# Epoch 144/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1727 - rounded_accuracy: 0.9306 - val_loss: 0.1772 - val_rounded_accuracy: 0.9290
# Epoch 145/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1727 - rounded_accuracy: 0.9305 - val_loss: 0.1781 - val_rounded_accuracy: 0.9261
# Epoch 146/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1727 - rounded_accuracy: 0.9306 - val_loss: 0.1774 - val_rounded_accuracy: 0.9278
# Epoch 147/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1727 - rounded_accuracy: 0.9306 - val_loss: 0.1775 - val_rounded_accuracy: 0.9278
# Epoch 148/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1725 - rounded_accuracy: 0.9306 - val_loss: 0.1775 - val_rounded_accuracy: 0.9293
# Epoch 149/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1726 - rounded_accuracy: 0.9306 - val_loss: 0.1777 - val_rounded_accuracy: 0.9273
# Epoch 150/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1726 - rounded_accuracy: 0.9307 - val_loss: 0.1777 - val_rounded_accuracy: 0.9282
# Epoch 151/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1726 - rounded_accuracy: 0.9306 - val_loss: 0.1773 - val_rounded_accuracy: 0.9286
# Epoch 152/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1725 - rounded_accuracy: 0.9307 - val_loss: 0.1781 - val_rounded_accuracy: 0.9255
# Epoch 153/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1725 - rounded_accuracy: 0.9307 - val_loss: 0.1777 - val_rounded_accuracy: 0.9282
# Epoch 154/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1724 - rounded_accuracy: 0.9306 - val_loss: 0.1767 - val_rounded_accuracy: 0.9290
# Epoch 155/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1724 - rounded_accuracy: 0.9308 - val_loss: 0.1769 - val_rounded_accuracy: 0.9296
# Epoch 156/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1724 - rounded_accuracy: 0.9308 - val_loss: 0.1778 - val_rounded_accuracy: 0.9282
# Epoch 157/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1724 - rounded_accuracy: 0.9308 - val_loss: 0.1771 - val_rounded_accuracy: 0.9276
# Epoch 158/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1725 - rounded_accuracy: 0.9307 - val_loss: 0.1775 - val_rounded_accuracy: 0.9284
# Epoch 159/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1725 - rounded_accuracy: 0.9307 - val_loss: 0.1778 - val_rounded_accuracy: 0.9275
# Epoch 160/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1724 - rounded_accuracy: 0.9309 - val_loss: 0.1774 - val_rounded_accuracy: 0.9281
# Epoch 161/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1723 - rounded_accuracy: 0.9308 - val_loss: 0.1775 - val_rounded_accuracy: 0.9271
# Epoch 162/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1723 - rounded_accuracy: 0.9308 - val_loss: 0.1770 - val_rounded_accuracy: 0.9295
# Epoch 163/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1725 - rounded_accuracy: 0.9308 - val_loss: 0.1774 - val_rounded_accuracy: 0.9285
# Epoch 164/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1724 - rounded_accuracy: 0.9308 - val_loss: 0.1772 - val_rounded_accuracy: 0.9287
# Epoch 165/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1723 - rounded_accuracy: 0.9309 - val_loss: 0.1772 - val_rounded_accuracy: 0.9287
# Epoch 166/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1723 - rounded_accuracy: 0.9308 - val_loss: 0.1771 - val_rounded_accuracy: 0.9293
# Epoch 167/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1722 - rounded_accuracy: 0.9308 - val_loss: 0.1784 - val_rounded_accuracy: 0.9259
# Epoch 168/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1722 - rounded_accuracy: 0.9309 - val_loss: 0.1774 - val_rounded_accuracy: 0.9277
# Epoch 169/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1723 - rounded_accuracy: 0.9308 - val_loss: 0.1773 - val_rounded_accuracy: 0.9295
# Epoch 170/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1722 - rounded_accuracy: 0.9309 - val_loss: 0.1769 - val_rounded_accuracy: 0.9294
# Epoch 171/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1722 - rounded_accuracy: 0.9309 - val_loss: 0.1775 - val_rounded_accuracy: 0.9294
# Epoch 172/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1721 - rounded_accuracy: 0.9309 - val_loss: 0.1780 - val_rounded_accuracy: 0.9283
# Epoch 173/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1721 - rounded_accuracy: 0.9309 - val_loss: 0.1769 - val_rounded_accuracy: 0.9292
# Epoch 174/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1721 - rounded_accuracy: 0.9310 - val_loss: 0.1771 - val_rounded_accuracy: 0.9293
# Epoch 175/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9310 - val_loss: 0.1771 - val_rounded_accuracy: 0.9289
# Epoch 176/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1721 - rounded_accuracy: 0.9310 - val_loss: 0.1775 - val_rounded_accuracy: 0.9290
# Epoch 177/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1719 - rounded_accuracy: 0.9311 - val_loss: 0.1778 - val_rounded_accuracy: 0.9286
# Epoch 178/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9309 - val_loss: 0.1772 - val_rounded_accuracy: 0.9289
# Epoch 179/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1721 - rounded_accuracy: 0.9311 - val_loss: 0.1772 - val_rounded_accuracy: 0.9281
# Epoch 180/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9309 - val_loss: 0.1768 - val_rounded_accuracy: 0.9299
# Epoch 181/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1719 - rounded_accuracy: 0.9310 - val_loss: 0.1775 - val_rounded_accuracy: 0.9281
# Epoch 182/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1721 - rounded_accuracy: 0.9311 - val_loss: 0.1765 - val_rounded_accuracy: 0.9299
# Epoch 183/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9311 - val_loss: 0.1774 - val_rounded_accuracy: 0.9281
# Epoch 184/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1719 - rounded_accuracy: 0.9310 - val_loss: 0.1773 - val_rounded_accuracy: 0.9293
# Epoch 185/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1718 - rounded_accuracy: 0.9311 - val_loss: 0.1771 - val_rounded_accuracy: 0.9290
# Epoch 186/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9310 - val_loss: 0.1773 - val_rounded_accuracy: 0.9294
# Epoch 187/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1719 - rounded_accuracy: 0.9311 - val_loss: 0.1771 - val_rounded_accuracy: 0.9294
# Epoch 188/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9311 - val_loss: 0.1771 - val_rounded_accuracy: 0.9295
# Epoch 189/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1718 - rounded_accuracy: 0.9310 - val_loss: 0.1773 - val_rounded_accuracy: 0.9293
# Epoch 190/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1718 - rounded_accuracy: 0.9311 - val_loss: 0.1771 - val_rounded_accuracy: 0.9287
# Epoch 191/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1719 - rounded_accuracy: 0.9312 - val_loss: 0.1770 - val_rounded_accuracy: 0.9293
# Epoch 192/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1718 - rounded_accuracy: 0.9311 - val_loss: 0.1775 - val_rounded_accuracy: 0.9289
# Epoch 193/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1719 - rounded_accuracy: 0.9311 - val_loss: 0.1771 - val_rounded_accuracy: 0.9285
# Epoch 194/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9311 - val_loss: 0.1768 - val_rounded_accuracy: 0.9296
# Epoch 195/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1719 - rounded_accuracy: 0.9311 - val_loss: 0.1778 - val_rounded_accuracy: 0.9284
# Epoch 196/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1718 - rounded_accuracy: 0.9312 - val_loss: 0.1770 - val_rounded_accuracy: 0.9293
# Epoch 197/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1717 - rounded_accuracy: 0.9312 - val_loss: 0.1776 - val_rounded_accuracy: 0.9285
# Epoch 198/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1718 - rounded_accuracy: 0.9312 - val_loss: 0.1779 - val_rounded_accuracy: 0.9281
# Epoch 199/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1720 - rounded_accuracy: 0.9312 - val_loss: 0.1771 - val_rounded_accuracy: 0.9293
# Epoch 200/200
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1718 - rounded_accuracy: 0.9312 - val_loss: 0.1777 - val_rounded_accuracy: 0.9288

# %%
#Graficamos el loss de entrenamiento y validación
plt.plot(history.history["loss"],label="Loss")
plt.plot(history.history["val_loss"],label="Val_loss")
plt.grid(True)
#plt.xlim(0,20)
#plt.ylim(0.49,0.52)
plt.legend()
plt.show()

# %%
#Graficamos el accuracy de entrenamiento y el de validación

plt.plot(history.history["rounded_accuracy"],label="Accuracy")
plt.plot(history.history["val_rounded_accuracy"],label="Val_Accuracy")
plt.grid(True)
#plt.xlim(0,20)
#plt.ylim(0.7,0.75)
plt.legend()
plt.show()

# %%
#Visualizamos las reconstrucciones usando la funcion ya definida
show_reconstructions(vae)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
#Hacemos un mapa de calor para visualizar la distribucion de las medias definidas para cada dato en el encoder
mean, *_ = vae.encoder.predict(X_train)
fig = plt.figure(figsize=(11, 7))
plt.scatter(mean[:, 0], mean[:, 1], c=y_train, cmap="magma")
plt.colorbar()
plt.show()
# Out:
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
#Para revisar el espacio latente usamos PCA y TSNE
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# Extraer los valores latentes
z_mean, _ = vae.encoder.predict(X_test)

# Aplicar PCA
pca = PCA(n_components=2)
z_pca = pca.fit_transform(z_mean)

# Aplicar TSNE
tsne = TSNE(n_components=2)
z_tsne = tsne.fit_transform(z_mean)

# Graficar los resultados
plt.figure(figsize=(12, 6))

# PCA
plt.subplot(1, 2, 1)
plt.scatter(z_pca[:, 0], z_pca[:, 1], c='blue', s=2)
plt.title('PCA del espacio latente')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')

# TSNE
plt.subplot(1, 2, 2)
plt.scatter(z_tsne[:, 0], z_tsne[:, 1], c='red', s=2)
plt.title('TSNE del espacio latente')
plt.xlabel('TSNE 1')
plt.ylabel('TSNE 2')

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
