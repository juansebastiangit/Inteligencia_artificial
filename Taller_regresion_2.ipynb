# %% [markdown]
# <a href="https://colab.research.google.com/github/juansebastiangit/Inteligencia_artificial/blob/main/Taller_regresion_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Taller 1 TAM - Regresores - Parte 2

# %% [markdown]
# # Ejemplo completo para un problema de regresión usando sci-kitlearn
#
# El siguiente ejemplo presenta las etapas básicas de un proyecto de analítica de datos en una tarea de regresión, orientadas a:
#
# - Preproceso de atributos con campos vacios y tipo texto.
# - Entrenamiento y selección de un modelo de regresión bajo una estrategia de validación cruzada.
# - La utilización de diccionarios para la sintonización de hiperparámetros.
# -Se ilustra también la creación de clases (objetos) propios compatibles con la clase pipeline de sci-kitlearn.
#
# **Base de datos utilizada**: [FIFA 2019 - Kaggle](https://www.kaggle.com/datasets/devansodariya/football-fifa-2019-dataset).

# %%
#cargar datos desde drive acceso libre
FILEID = "15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O codigos.zip && rm -rf /tmp/cookies.txt
# !unzip codigos.zip
# !dir
# Out:
# --2024-12-12 19:56:18--  https://docs.google.com/uc?export=download&confirm=&id=15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe
# Resolving docs.google.com (docs.google.com)... 74.125.199.102, 74.125.199.138, 74.125.199.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.199.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe&export=download [following]
# --2024-12-12 19:56:19--  https://drive.usercontent.google.com/download?id=15QxsIm_jMfHEy6Y--6o19IWgr66oiTRe&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.142.132, 2607:f8b0:400e:c08::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.142.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4039371 (3.9M) [application/octet-stream]
# Saving to: ‘codigos.zip’
#
# codigos.zip         100%[===================>]   3.85M  --.-KB/s    in 0.04s
#
# 2024-12-12 19:56:23 (110 MB/s) - ‘codigos.zip’ saved [4039371/4039371]
#
# Archive:  codigos.zip
#    creating: Main_Fifa/
#   inflating: Main_Fifa/main_fifa.ipynb
#   inflating: Main_Fifa/funciones_fifa.py
#    creating: Main_Fifa/.ipynb_checkpoints/
#   inflating: Main_Fifa/.ipynb_checkpoints/main_fifa-checkpoint.ipynb
#   inflating: Main_Fifa/.ipynb_checkpoints/KinectDatos-checkpoint.ipynb
#   inflating: Main_Fifa/.ipynb_checkpoints/desktop.ini
#    creating: Main_Fifa/im2/
#   inflating: Main_Fifa/im2/tsne_2D.png
#   inflating: Main_Fifa/im2/relevancia_PCA.png
#   inflating: Main_Fifa/im2/red_PCA2D.png
#   inflating: Main_Fifa/im2/mae_testing_set.png
#   inflating: Main_Fifa/im2/desktop.ini
#    creating: Main_Fifa/__pycache__/
#   inflating: Main_Fifa/__pycache__/funciones_fifa.cpython-37.pyc
#   inflating: Main_Fifa/__pycache__/funciones_housing.cpython-37.pyc
#   inflating: Main_Fifa/__pycache__/desktop.ini
#   inflating: Main_Fifa/debug.log
#    creating: Main_Fifa/datos/
#   inflating: Main_Fifa/datos/data.csv
#   inflating: Main_Fifa/datos/desktop.ini
#    creating: Main_Fifa/resultados/
#   inflating: Main_Fifa/resultados/tsne_2D.png
#   inflating: Main_Fifa/resultados/tsne_PCA2D.png
#   inflating: Main_Fifa/resultados/mae_testing_set.png
#   inflating: Main_Fifa/resultados/relevancia_PCA.png
#   inflating: Main_Fifa/resultados/red_PCA2D.png
#   inflating: Main_Fifa/resultados/desktop.ini
#   inflating: Main_Fifa/desktop.ini
# codigos.zip  Main_Fifa	sample_data

# %% [markdown]
# # Lectura de la base de datos con Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

#librerias para proceso
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score, cross_val_predict
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import Pipeline

# %matplotlib inline
csv_path = 'Main_Fifa/datos/data.csv' #directorio de la base de datos en disco de colaboratory según archivo cargado

Xdata = pd.read_csv(csv_path)#leer archivo csv

col_drop = ['Unnamed: 0', 'Name','ID','Photo','Flag',
           'Club Logo','Loaned From'] #variables a descartar - no contienen información relevante
Xdata.drop(columns = col_drop, inplace = True)
Xdata.head()
# Out:
#    Age Nationality  Overall  Potential                 Club    Value   Wage  \
# 0   31   Argentina       94         94         FC Barcelona  €110.5M  €565K
# 1   33    Portugal       94         94             Juventus     €77M  €405K
# 2   26      Brazil       92         93  Paris Saint-Germain  €118.5M  €290K
# 3   27       Spain       91         93    Manchester United     €72M  €260K
# 4   27     Belgium       91         92      Manchester City    €102M  €355K
#
#    Special Preferred Foot  International Reputation  ...  Composure  Marking  \
# 0     2202           Left                       5.0  ...       96.0     33.0
# 1     2228          Right                       5.0  ...       95.0     28.0
# 2     2143          Right                       5.0  ...       94.0     27.0
# 3     1471          Right                       4.0  ...       68.0     15.0
# 4     2281          Right                       4.0  ...       88.0     68.0
#
#   StandingTackle SlidingTackle GKDiving GKHandling  GKKicking GKPositioning  \
# 0           28.0          26.0      6.0       11.0       15.0          14.0
# 1           31.0          23.0      7.0       11.0       15.0          14.0
# 2           24.0          33.0      9.0        9.0       15.0          15.0
# 3           21.0          13.0     90.0       85.0       87.0          88.0
# 4           58.0          51.0     15.0       13.0        5.0          10.0
#
#   GKReflexes Release Clause
# 0        8.0        €226.5M
# 1       11.0        €127.1M
# 2       11.0        €228.1M
# 3       94.0        €138.6M
# 4       13.0        €196.4M
#
# [5 rows x 82 columns]

# %% [markdown]
# # Identificar tipos de variables, campos perdidos y preproceso básico a realizar

# %%
Xdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       18207 non-null  int64
#  1   Nationality               18207 non-null  object
#  2   Overall                   18207 non-null  int64
#  3   Potential                 18207 non-null  int64
#  4   Club                      17966 non-null  object
#  5   Value                     18207 non-null  object
#  6   Wage                      18207 non-null  object
#  7   Special                   18207 non-null  int64
#  8   Preferred Foot            18159 non-null  object
#  9   International Reputation  18159 non-null  float64
#  10  Weak Foot                 18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Work Rate                 18159 non-null  object
#  13  Body Type                 18159 non-null  object
#  14  Real Face                 18159 non-null  object
#  15  Position                  18147 non-null  object
#  16  Jersey Number             18147 non-null  float64
#  17  Joined                    16654 non-null  object
#  18  Contract Valid Until      17918 non-null  object
#  19  Height                    18159 non-null  object
#  20  Weight                    18159 non-null  object
#  21  LS                        16122 non-null  object
#  22  ST                        16122 non-null  object
#  23  RS                        16122 non-null  object
#  24  LW                        16122 non-null  object
#  25  LF                        16122 non-null  object
#  26  CF                        16122 non-null  object
#  27  RF                        16122 non-null  object
#  28  RW                        16122 non-null  object
#  29  LAM                       16122 non-null  object
#  30  CAM                       16122 non-null  object
#  31  RAM                       16122 non-null  object
#  32  LM                        16122 non-null  object
#  33  LCM                       16122 non-null  object
#  34  CM                        16122 non-null  object
#  35  RCM                       16122 non-null  object
#  36  RM                        16122 non-null  object
#  37  LWB                       16122 non-null  object
#  38  LDM                       16122 non-null  object
#  39  CDM                       16122 non-null  object
#  40  RDM                       16122 non-null  object
#  41  RWB                       16122 non-null  object
#  42  LB                        16122 non-null  object
#  43  LCB                       16122 non-null  object
#  44  CB                        16122 non-null  object
#  45  RCB                       16122 non-null  object
#  46  RB                        16122 non-null  object
#  47  Crossing                  18159 non-null  float64
#  48  Finishing                 18159 non-null  float64
#  49  HeadingAccuracy           18159 non-null  float64
#  50  ShortPassing              18159 non-null  float64
#  51  Volleys                   18159 non-null  float64
#  52  Dribbling                 18159 non-null  float64
#  53  Curve                     18159 non-null  float64
#  54  FKAccuracy                18159 non-null  float64
#  55  LongPassing               18159 non-null  float64
#  56  BallControl               18159 non-null  float64
#  57  Acceleration              18159 non-null  float64
#  58  SprintSpeed               18159 non-null  float64
#  59  Agility                   18159 non-null  float64
#  60  Reactions                 18159 non-null  float64
#  61  Balance                   18159 non-null  float64
#  62  ShotPower                 18159 non-null  float64
#  63  Jumping                   18159 non-null  float64
#  64  Stamina                   18159 non-null  float64
#  65  Strength                  18159 non-null  float64
#  66  LongShots                 18159 non-null  float64
#  67  Aggression                18159 non-null  float64
#  68  Interceptions             18159 non-null  float64
#  69  Positioning               18159 non-null  float64
#  70  Vision                    18159 non-null  float64
#  71  Penalties                 18159 non-null  float64
#  72  Composure                 18159 non-null  float64
#  73  Marking                   18159 non-null  float64
#  74  StandingTackle            18159 non-null  float64
#  75  SlidingTackle             18159 non-null  float64
#  76  GKDiving                  18159 non-null  float64
#  77  GKHandling                18159 non-null  float64
#  78  GKKicking                 18159 non-null  float64
#  79  GKPositioning             18159 non-null  float64
#  80  GKReflexes                18159 non-null  float64
#  81  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(4), object(40)
# memory usage: 11.4+ MB

# %% [markdown]
# ## Se presentan atributos tipo int, float y texto, algunos de ellos con datos perdidos.

# %% [markdown]
# # Partición en conjunto de training y testing.
#
# ## Tips básicos para escoger la estrategia de validación:
#
# - Para $N\geq 5000$ se sugiere realizar entrenamiento hold-out, generando grupos de entrenamiento, validación y evaluación. Los conjuntos de entrenamiento y validación se pueden utilizar para realizar validación cruzada de 10 o 5 folds para determinar el mejor modelo y sus hiperparámetros.
#
# - No obstante, si la cantidad de datos es muy grande, generalmente se utiliza un único conjunto de entrenamiento y un único conjunto de validación, e.g., modelos de deep learning generalmente utilizan esta estrategia por la gran cantidad de datos disponible.
#
# **HoldOut con única partición de entrenamiento, validación y evaluación (training, validation, testing)**
#
# ![HoldOut](https://github.com/amalvarezme/AprendizajeMaquina/blob/main/3_Intro_Sklearn_Regresion/HoldOut.png?raw=1)
#
#
# **HoldOut utilizando validación cruzada para definir varios conjuntos de entrenamiento y validación en la búsqueda del mejor modelo con evaluación final en un único conjunto de testing**
#
# ![grid_search_cross_validation](https://github.com/amalvarezme/AprendizajeMaquina/blob/main/3_Intro_Sklearn_Regresion/crossvalidation.png?raw=1)
#
# - Se sugiere para $ 30 <N <5000$ realizar validación cruzada o validación cruzada anidad k folds (generalmente se trabaja con k=10 o k = 5), y reportar el desempeño promedio en el conjunto de test a lo largo de las rotaciones.
#
# - En algunos textos, dado que los datos se rotan y aparecen al menos una vez en el conjunto de training y una vez en el de testing, se habla solamente de conjuntos de entrenamiento y validación, porque el concepto de datos afuera (testing) se pierde.
#
# ![kfolds](https://github.com/amalvarezme/AprendizajeMaquina/blob/main/3_Intro_Sklearn_Regresion/kfolds.png?raw=1)
#
# - La validación cruzada anidad es mucho más estricta a la hora de dejar un conjunto de test que no se utiliza para sintonizar los hiperparámetros (a diferencia del kfolds convencional que determina los mejores valores de hiperparámetros respecto al conjunto de validación=evaluación). Sin embargo, la validación anidad es más costosa computacionalmente.
#
#
# ![nestedcv](https://github.com/amalvarezme/AprendizajeMaquina/blob/main/3_Intro_Sklearn_Regresion/nestedcv.png?raw=1)
#
# - Para $N \leq 30$ se sugiere trabajar con validación cruzada fijando el número de particiones igual al número de datos ($k=N$). En este caso, se tiene un conjunto de entrenamiento de $N-1$ y una única muestra de test que se rota $N$ veces (leave-one-out).
#
#
#
# **Nota**: Para el ejemplo ilustrado se cuenta con una buena cantidad de datos 18.000 aprox., por lo que se realizará una validación hold-out, con 70% de datos para entrenamiento y 30% para evaluación. Sobre el conjunto de entrenamiento se realizará una validación cruzada de 5 folds (k=5) para determinar el mejor modelo e hiperparámetros.
#
# Se define el atributo Release Clause como salida.

# %%
# Partición entrenamiento y evaluación
# Tamaño Xtrain 70%, Tamaño Xtest 30%

Xtrain, Xtest = train_test_split(Xdata,test_size=0.3)
col_sal = "Release Clause"
ytrain = Xtrain[col_sal]
ytest = Xtest[col_sal]
Xtrain_1 = Xtrain
Xtrain.drop(columns=col_sal,inplace=True)
Xtest.drop(columns=col_sal,inplace=True)

# %% [markdown]
# **Nota**: Recuerde que puede usar la partición estratificada para preservar la distribución de la salida de interés en los folds

# %% [markdown]
# # Preproceso: completar datos y codificar datos tipo texto

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="most_frequent")#se utiliza estimador de moda
ytrain = imputer.fit_transform(pd.DataFrame(ytrain)).reshape(-1)#ajuste sobre la salida
ytest = imputer.transform(pd.DataFrame(ytest)).reshape(-1)#evaluar sobre datos de test

print(ytrain.shape, ytest.shape)
# Out:
# (12744,) (5463,)

# %% [markdown]
# **Nota**: Dado que la variable de salida esta en formato moneda se debe codificar meidante función particular (custom). También, se creará una función para codificar las variables tipo evolución características del jugador.
#
# ---

# %%
ytrain[0]
# Out:
# '€144K'

# %%
 #codificar variables moneda
def code_euro(y):
    yc = np.zeros(y.shape[0])
    for i in range(y.shape[0]):
        if y[i][-1]=='M': yc[i] = float(y[i][1:-1])*10**6 #buscar M y reemplazar 10^6
        elif y[i][-1]=='K': yc[i] = float(y[i][1:-1])*10**3 # buscar K y reemplazar por 10^3
        else: yc[i] = float(y[i][1:])
    return yc

#codificar estadísticas
def code_stats(y):
    yc = np.zeros(y.shape[0])
    for i in range(y.shape[0]):
        if y.iloc[i].find("+") > -1: # encontrar signo + en str y casteo a flotante
            yc[i] = float(y.iloc[i][:y.iloc[i].find("+")])+float(y.iloc[i][y.iloc[i].find("+")+1:])
        else: yc[i] = float(y.iloc[i])
    return yc

# %%
#codificar salida
ytrain_num = code_euro(ytrain)
ytest_num = code_euro(ytest)

# %%
ytrain_num[:5]
# Out:
# array([  144000., 31500000.,   760000.,  1100000.,   819000.])

# %% [markdown]
# ## Se definen las variables para codificar utilizando las funciones establecidas de moneda, estadísticas y las tipo texto con OrdinalEncoder y OneHotEncoder.

# %%
#definir columnas tipo string  para codificar moneda, estadistica fifa y categoricas
col_euro = ['Value','Wage'] #variables tipo moneda
col_stats = ['LS','ST','RS','LW','LF','CF','RF','RW','LAM',
             'CAM','RAM','LM','LCM','CM','RCM','RM','LWB',
             'LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB']#variables tipo mejora jugadores

cat = ['Nationality','Club','Body Type','Position','Preferred Foot',
        'Work Rate','Real Face','Contract Valid Until']#variables a codificar OrdinalEncoder y OneHotEncoder
items = []
for i in cat:
    items += [list(Xdata[i].value_counts().index)]
cat_usr = dict(zip(cat, items))#se crean diccionarios con las variables y sus posibles valores

# %%
Xdata['Nationality'].value_counts()
# Out:
# Nationality
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: count, Length: 164, dtype: int64

# %%
cat_usr.keys()
# Out:
# dict_keys(['Nationality', 'Club', 'Body Type', 'Position', 'Preferred Foot', 'Work Rate', 'Real Face', 'Contract Valid Until'])

# %%
cat_usr['Body Type']
# Out:
# ['Normal',
#  'Lean',
#  'Stocky',
#  'Messi',
#  'C. Ronaldo',
#  'Neymar',
#  'Courtois',
#  'PLAYER_BODY_TYPE_25',
#  'Shaqiri',
#  'Akinfenwa']

# %% [markdown]
# # Se crea clase propia (custom) para ejecutar el preproceso que sea compatible con scikitlearn

# %%
#%% transformer custom
from sklearn.base import BaseEstimator, TransformerMixin #objetos básicos para herencia de clase

class mypre_fifa(BaseEstimator,TransformerMixin):
    #inicializacion de clase y varaibles
    def __init__(self, col_euro,col_stats, cat_usr): #constructor clase
        self.col_euro = col_euro #lista atributos tipo moneda
        self.col_stats = col_stats #lista atributos tipo estadistica
        self.cat_usr = cat_usr #lista de atributos categoricos

    def fit(self,X, *_):#función de ajuste -> *_ para indicar que puede recibir más entradas en el pipeline
        Xi = X.copy() #copiar dataset para no reemplazar original
        self.imputer_num = SimpleImputer(strategy="most_frequent") #crear imputador tipo moda
        self.a = Xi.columns[np.sum(Xi.isna())> 0] #encontrar columnas con datos faltantes
        self.imputer_num.fit(Xi[self.a]) # ajustar imputador
        Xi[self.a] = self.imputer_num.transform(Xi[self.a]) #evaluar datos con el imputador

        for i in self.col_euro: #codificar tipo moneda
            Xi[i] = code_euro(np.array(Xi[i]))

        for i in self.col_stats: #codificar datos estadisticos
            Xi[i] = code_stats(Xi[i])

        #height, wieght corregir formato
        Xi['Height'].replace(regex=["'"], value='.',inplace=True) #reemplaza unidad ' con .
        for i in Xi.index:
            Xi.loc[i,'Weight'] = float(Xi.loc[i,'Weight'][:-3])#elimnar unidades
            Xi.loc[i,'Height'] = float(Xi.loc[i,'Height'])#eliminar unidades

        Xi['Height'] = Xi['Height'].astype('float64')
        Xi['Weight'] = Xi['Weight'].astype('float64')#asegurar formato flotante

        Xi['Joined'] = Xi['Joined'].replace(regex="/",value="")#codificar fecha
        Xi['Joined'] = Xi['Joined'].astype('float64')

        cat = [] #codificar variables categoricas con ordinal encoder
        for i in self.cat_usr.keys():
            cat = cat + [[*self.cat_usr.get(i)]]
        self.col_cat_usr = OrdinalEncoder(categories=cat) # OneHotEncoder(categories=cat,sparse=False)
        Xi[[*self.cat_usr.keys()]] =self.col_cat_usr.fit_transform(Xi[[*self.cat_usr.keys()]])
        #si utilizar OneHotEncoder debe concatenar las columnas resultantes -> ver cuaderno guia lado a lado

        return self

    def transform(self, X, *_):#funcion transformador-> pensando en datos nuevos
        Xi = X.copy()
        Xi[self.a] = self.imputer_num.transform(Xi[self.a])

        for i in self.col_euro:
            Xi[i] = code_euro(np.array(Xi[i]))
        for i in self.col_stats:
            Xi[i] = code_stats(Xi[i])

                #height, wieght
        Xi['Height'].replace(regex=["'"], value='.',inplace=True)
        for i in Xi.index:
            Xi.loc[i,'Weight'] = float(Xi.loc[i,'Weight'][:-3])
            Xi.loc[i,'Height'] = float(Xi.loc[i,'Height'])

        Xi['Height'] = Xi['Height'].astype('float64')
        Xi['Weight'] = Xi['Weight'].astype('float64')

        Xi['Joined'] = Xi['Joined'].replace(regex="/",value="")
        Xi['Joined'] = Xi['Joined'].astype('float64')

        Xi[[*self.cat_usr.keys()]] =self.col_cat_usr.transform(Xi[[*self.cat_usr.keys()]])
        return Xi

    def fit_transform(self,X,*_):#ajustar y transformar en cascada
        self.fit(X)
        return self.transform(X)

# %%
mypre = mypre_fifa(col_euro=col_euro,col_stats=col_stats,cat_usr = cat_usr)
Xtrain_pre = mypre.fit_transform(Xtrain)

# %% [markdown]
# **Nota**: Recuerde que ninguna etapa del proceso puede utilizar los datos de test para sintonizar parámetros.

# %%
Xtest_pre = mypre.transform(Xtest) #no se puede fit solo transform-> parámetros ajustados sobre Xtrain

# %%
Xtrain_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12744 entries, 18024 to 10688
# Data columns (total 81 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       12744 non-null  int64
#  1   Nationality               12744 non-null  float64
#  2   Overall                   12744 non-null  int64
#  3   Potential                 12744 non-null  int64
#  4   Club                      12744 non-null  float64
#  5   Value                     12744 non-null  float64
#  6   Wage                      12744 non-null  float64
#  7   Special                   12744 non-null  int64
#  8   Preferred Foot            12744 non-null  float64
#  9   International Reputation  12744 non-null  object
#  10  Weak Foot                 12744 non-null  object
#  11  Skill Moves               12744 non-null  object
#  12  Work Rate                 12744 non-null  float64
#  13  Body Type                 12744 non-null  float64
#  14  Real Face                 12744 non-null  float64
#  15  Position                  12744 non-null  float64
#  16  Jersey Number             12744 non-null  object
#  17  Joined                    12744 non-null  float64
#  18  Contract Valid Until      12744 non-null  float64
#  19  Height                    12744 non-null  float64
#  20  Weight                    12744 non-null  float64
#  21  LS                        12744 non-null  float64
#  22  ST                        12744 non-null  float64
#  23  RS                        12744 non-null  float64
#  24  LW                        12744 non-null  float64
#  25  LF                        12744 non-null  float64
#  26  CF                        12744 non-null  float64
#  27  RF                        12744 non-null  float64
#  28  RW                        12744 non-null  float64
#  29  LAM                       12744 non-null  float64
#  30  CAM                       12744 non-null  float64
#  31  RAM                       12744 non-null  float64
#  32  LM                        12744 non-null  float64
#  33  LCM                       12744 non-null  float64
#  34  CM                        12744 non-null  float64
#  35  RCM                       12744 non-null  float64
#  36  RM                        12744 non-null  float64
#  37  LWB                       12744 non-null  float64
#  38  LDM                       12744 non-null  float64
#  39  CDM                       12744 non-null  float64
#  40  RDM                       12744 non-null  float64
#  41  RWB                       12744 non-null  float64
#  42  LB                        12744 non-null  float64
#  43  LCB                       12744 non-null  float64
#  44  CB                        12744 non-null  float64
#  45  RCB                       12744 non-null  float64
#  46  RB                        12744 non-null  float64
#  47  Crossing                  12744 non-null  object
#  48  Finishing                 12744 non-null  object
#  49  HeadingAccuracy           12744 non-null  object
#  50  ShortPassing              12744 non-null  object
#  51  Volleys                   12744 non-null  object
#  52  Dribbling                 12744 non-null  object
#  53  Curve                     12744 non-null  object
#  54  FKAccuracy                12744 non-null  object
#  55  LongPassing               12744 non-null  object
#  56  BallControl               12744 non-null  object
#  57  Acceleration              12744 non-null  object
#  58  SprintSpeed               12744 non-null  object
#  59  Agility                   12744 non-null  object
#  60  Reactions                 12744 non-null  object
#  61  Balance                   12744 non-null  object
#  62  ShotPower                 12744 non-null  object
#  63  Jumping                   12744 non-null  object
#  64  Stamina                   12744 non-null  object
#  65  Strength                  12744 non-null  object
#  66  LongShots                 12744 non-null  object
#  67  Aggression                12744 non-null  object
#  68  Interceptions             12744 non-null  object
#  69  Positioning               12744 non-null  object
#  70  Vision                    12744 non-null  object
#  71  Penalties                 12744 non-null  object
#  72  Composure                 12744 non-null  object
#  73  Marking                   12744 non-null  object
#  74  StandingTackle            12744 non-null  object
#  75  SlidingTackle             12744 non-null  object
#  76  GKDiving                  12744 non-null  object
#  77  GKHandling                12744 non-null  object
#  78  GKKicking                 12744 non-null  object
#  79  GKPositioning             12744 non-null  object
#  80  GKReflexes                12744 non-null  object
# dtypes: float64(39), int64(4), object(38)
# memory usage: 8.5+ MB

# %% [markdown]
# Las variables fueron codificadas $X_{train}\in\mathbb{R}^{N \times P}$

# %% [markdown]
# # Se realiza análisis exploratorio básico

# %%
corr_matrix = Xtrain_pre.corr()#matriz de correlación
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b6243_row0_col0, #T_b6243_row1_col1, #T_b6243_row2_col2, #T_b6243_row3_col3, #T_b6243_row4_col4, #T_b6243_row5_col5, #T_b6243_row6_col6, #T_b6243_row7_col7, #T_b6243_row8_col8, #T_b6243_row9_col9, #T_b6243_row10_col10, #T_b6243_row11_col11, #T_b6243_row12_col12, #T_b6243_row13_col13, #T_b6243_row14_col14, #T_b6243_row15_col15, #T_b6243_row16_col16, #T_b6243_row17_col17, #T_b6243_row18_col18, #T_b6243_row19_col19, #T_b6243_row20_col20, #T_b6243_row21_col21, #T_b6243_row21_col22, #T_b6243_row21_col23, #T_b6243_row22_col21, #T_b6243_row22_col22, #T_b6243_row22_col23, #T_b6243_row23_col21, #T_b6243_row23_col22, #T_b6243_row23_col23, #T_b6243_row24_col24, #T_b6243_row24_col28, #T_b6243_row25_col25, #T_b6243_row25_col26, #T_b6243_row25_col27, #T_b6243_row26_col25, #T_b6243_row26_col26, #T_b6243_row26_col27, #T_b6243_row27_col25, #T_b6243_row27_col26, #T_b6243_row27_col27, #T_b6243_row28_col24, #T_b6243_row28_col28, #T_b6243_row29_col29, #T_b6243_row29_col30, #T_b6243_row29_col31, #T_b6243_row30_col29, #T_b6243_row30_col30, #T_b6243_row30_col31, #T_b6243_row31_col29, #T_b6243_row31_col30, #T_b6243_row31_col31, #T_b6243_row32_col32, #T_b6243_row32_col36, #T_b6243_row33_col33, #T_b6243_row33_col34, #T_b6243_row33_col35, #T_b6243_row34_col33, #T_b6243_row34_col34, #T_b6243_row34_col35, #T_b6243_row35_col33, #T_b6243_row35_col34, #T_b6243_row35_col35, #T_b6243_row36_col32, #T_b6243_row36_col36, #T_b6243_row37_col37, #T_b6243_row37_col41, #T_b6243_row38_col38, #T_b6243_row38_col39, #T_b6243_row38_col40, #T_b6243_row39_col38, #T_b6243_row39_col39, #T_b6243_row39_col40, #T_b6243_row40_col38, #T_b6243_row40_col39, #T_b6243_row40_col40, #T_b6243_row41_col37, #T_b6243_row41_col41, #T_b6243_row42_col42, #T_b6243_row42_col46, #T_b6243_row43_col43, #T_b6243_row43_col44, #T_b6243_row43_col45, #T_b6243_row44_col43, #T_b6243_row44_col44, #T_b6243_row44_col45, #T_b6243_row45_col43, #T_b6243_row45_col44, #T_b6243_row45_col45, #T_b6243_row46_col42, #T_b6243_row46_col46, #T_b6243_row47_col47, #T_b6243_row48_col48, #T_b6243_row49_col49, #T_b6243_row50_col50, #T_b6243_row51_col51, #T_b6243_row52_col52, #T_b6243_row53_col53, #T_b6243_row54_col54, #T_b6243_row55_col55, #T_b6243_row56_col56, #T_b6243_row57_col57, #T_b6243_row58_col58, #T_b6243_row59_col59, #T_b6243_row60_col60, #T_b6243_row61_col61, #T_b6243_row62_col62, #T_b6243_row63_col63, #T_b6243_row64_col64, #T_b6243_row65_col65, #T_b6243_row66_col66, #T_b6243_row67_col67, #T_b6243_row68_col68, #T_b6243_row69_col69, #T_b6243_row70_col70, #T_b6243_row71_col71, #T_b6243_row72_col72, #T_b6243_row73_col73, #T_b6243_row74_col74, #T_b6243_row75_col75, #T_b6243_row76_col76, #T_b6243_row77_col77, #T_b6243_row78_col78, #T_b6243_row79_col79, #T_b6243_row80_col80 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b6243_row0_col1, #T_b6243_row19_col1, #T_b6243_row50_col1, #T_b6243_row68_col24, #T_b6243_row68_col28, #T_b6243_row69_col76, #T_b6243_row69_col77, #T_b6243_row69_col78, #T_b6243_row69_col79, #T_b6243_row69_col80, #T_b6243_row74_col32, #T_b6243_row74_col36 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b6243_row0_col2, #T_b6243_row0_col7, #T_b6243_row3_col69, #T_b6243_row5_col51, #T_b6243_row5_col66, #T_b6243_row6_col62, #T_b6243_row14_col7, #T_b6243_row14_col9, #T_b6243_row14_col56, #T_b6243_row32_col37, #T_b6243_row32_col41, #T_b6243_row33_col43, #T_b6243_row33_col44, #T_b6243_row33_col45, #T_b6243_row34_col43, #T_b6243_row34_col44, #T_b6243_row34_col45, #T_b6243_row35_col43, #T_b6243_row35_col44, #T_b6243_row35_col45, #T_b6243_row36_col37, #T_b6243_row36_col41, #T_b6243_row50_col15, #T_b6243_row50_col32, #T_b6243_row50_col36, #T_b6243_row55_col32, #T_b6243_row55_col36, #T_b6243_row55_col37, #T_b6243_row55_col41, #T_b6243_row60_col68, #T_b6243_row63_col56, #T_b6243_row73_col72, #T_b6243_row74_col62 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_b6243_row0_col3, #T_b6243_row0_col16, #T_b6243_row3_col0, #T_b6243_row3_col4, #T_b6243_row4_col5, #T_b6243_row4_col6, #T_b6243_row4_col9, #T_b6243_row4_col14, #T_b6243_row14_col1, #T_b6243_row14_col4, #T_b6243_row16_col2, #T_b6243_row16_col33, #T_b6243_row16_col34, #T_b6243_row16_col35, #T_b6243_row16_col37, #T_b6243_row16_col41, #T_b6243_row16_col60, #T_b6243_row17_col18, #T_b6243_row18_col1, #T_b6243_row18_col17, #T_b6243_row19_col32, #T_b6243_row19_col33, #T_b6243_row19_col34, #T_b6243_row19_col35, #T_b6243_row19_col36, #T_b6243_row20_col13, #T_b6243_row20_col59, #T_b6243_row20_col61, #T_b6243_row48_col38, #T_b6243_row48_col39, #T_b6243_row48_col40, #T_b6243_row48_col42, #T_b6243_row48_col43, #T_b6243_row48_col44, #T_b6243_row48_col45, #T_b6243_row48_col46, #T_b6243_row56_col76, #T_b6243_row56_col77, #T_b6243_row56_col78, #T_b6243_row56_col79, #T_b6243_row56_col80, #T_b6243_row61_col19, #T_b6243_row61_col20, #T_b6243_row61_col65, #T_b6243_row75_col21, #T_b6243_row75_col22, #T_b6243_row75_col23, #T_b6243_row75_col24, #T_b6243_row75_col25, #T_b6243_row75_col26, #T_b6243_row75_col27, #T_b6243_row75_col28, #T_b6243_row75_col29, #T_b6243_row75_col30, #T_b6243_row75_col31, #T_b6243_row76_col1, #T_b6243_row76_col7, #T_b6243_row76_col8, #T_b6243_row76_col10, #T_b6243_row76_col11, #T_b6243_row76_col12, #T_b6243_row76_col15, #T_b6243_row76_col47, #T_b6243_row76_col48, #T_b6243_row76_col49, #T_b6243_row76_col50, #T_b6243_row76_col51, #T_b6243_row76_col52, #T_b6243_row76_col53, #T_b6243_row76_col54, #T_b6243_row76_col55, #T_b6243_row76_col56, #T_b6243_row76_col57, #T_b6243_row76_col58, #T_b6243_row76_col62, #T_b6243_row76_col63, #T_b6243_row76_col64, #T_b6243_row76_col66, #T_b6243_row76_col67, #T_b6243_row76_col68, #T_b6243_row76_col69, #T_b6243_row76_col70, #T_b6243_row76_col71, #T_b6243_row76_col72, #T_b6243_row76_col73, #T_b6243_row76_col74, #T_b6243_row76_col75, #T_b6243_row77_col1, #T_b6243_row77_col7, #T_b6243_row77_col8, #T_b6243_row77_col10, #T_b6243_row77_col11, #T_b6243_row77_col12, #T_b6243_row77_col15, #T_b6243_row77_col47, #T_b6243_row77_col48, #T_b6243_row77_col49, #T_b6243_row77_col50, #T_b6243_row77_col51, #T_b6243_row77_col52, #T_b6243_row77_col53, #T_b6243_row77_col54, #T_b6243_row77_col55, #T_b6243_row77_col56, #T_b6243_row77_col57, #T_b6243_row77_col58, #T_b6243_row77_col62, #T_b6243_row77_col63, #T_b6243_row77_col64, #T_b6243_row77_col66, #T_b6243_row77_col67, #T_b6243_row77_col68, #T_b6243_row77_col69, #T_b6243_row77_col70, #T_b6243_row77_col71, #T_b6243_row77_col72, #T_b6243_row77_col73, #T_b6243_row77_col74, #T_b6243_row77_col75, #T_b6243_row78_col7, #T_b6243_row78_col8, #T_b6243_row78_col10, #T_b6243_row78_col11, #T_b6243_row78_col12, #T_b6243_row78_col15, #T_b6243_row78_col47, #T_b6243_row78_col49, #T_b6243_row78_col50, #T_b6243_row78_col52, #T_b6243_row78_col55, #T_b6243_row78_col56, #T_b6243_row78_col57, #T_b6243_row78_col58, #T_b6243_row78_col62, #T_b6243_row78_col63, #T_b6243_row78_col64, #T_b6243_row78_col67, #T_b6243_row78_col68, #T_b6243_row78_col69, #T_b6243_row78_col71, #T_b6243_row78_col72, #T_b6243_row78_col73, #T_b6243_row78_col74, #T_b6243_row78_col75, #T_b6243_row79_col7, #T_b6243_row79_col8, #T_b6243_row79_col10, #T_b6243_row79_col11, #T_b6243_row79_col12, #T_b6243_row79_col15, #T_b6243_row79_col47, #T_b6243_row79_col48, #T_b6243_row79_col49, #T_b6243_row79_col50, #T_b6243_row79_col51, #T_b6243_row79_col52, #T_b6243_row79_col53, #T_b6243_row79_col54, #T_b6243_row79_col55, #T_b6243_row79_col56, #T_b6243_row79_col57, #T_b6243_row79_col58, #T_b6243_row79_col62, #T_b6243_row79_col64, #T_b6243_row79_col66, #T_b6243_row79_col67, #T_b6243_row79_col68, #T_b6243_row79_col69, #T_b6243_row79_col71, #T_b6243_row79_col73, #T_b6243_row79_col74, #T_b6243_row79_col75, #T_b6243_row80_col1, #T_b6243_row80_col7, #T_b6243_row80_col8, #T_b6243_row80_col10, #T_b6243_row80_col11, #T_b6243_row80_col12, #T_b6243_row80_col15, #T_b6243_row80_col47, #T_b6243_row80_col48, #T_b6243_row80_col49, #T_b6243_row80_col50, #T_b6 ...

# %%
Xtrain_pre2 = Xtrain_pre.copy()
Xtrain_pre2['output'] = ytrain_num
corr_matrix2 = Xtrain_pre2.corr()#matriz de correlación
corr_matrix2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_685f0_row0_col0, #T_685f0_row1_col1, #T_685f0_row2_col2, #T_685f0_row3_col3, #T_685f0_row4_col4, #T_685f0_row5_col5, #T_685f0_row6_col6, #T_685f0_row7_col7, #T_685f0_row8_col8, #T_685f0_row9_col9, #T_685f0_row10_col10, #T_685f0_row11_col11, #T_685f0_row12_col12, #T_685f0_row13_col13, #T_685f0_row14_col14, #T_685f0_row15_col15, #T_685f0_row16_col16, #T_685f0_row17_col17, #T_685f0_row18_col18, #T_685f0_row19_col19, #T_685f0_row20_col20, #T_685f0_row21_col21, #T_685f0_row21_col22, #T_685f0_row21_col23, #T_685f0_row22_col21, #T_685f0_row22_col22, #T_685f0_row22_col23, #T_685f0_row23_col21, #T_685f0_row23_col22, #T_685f0_row23_col23, #T_685f0_row24_col24, #T_685f0_row24_col28, #T_685f0_row25_col25, #T_685f0_row25_col26, #T_685f0_row25_col27, #T_685f0_row26_col25, #T_685f0_row26_col26, #T_685f0_row26_col27, #T_685f0_row27_col25, #T_685f0_row27_col26, #T_685f0_row27_col27, #T_685f0_row28_col24, #T_685f0_row28_col28, #T_685f0_row29_col29, #T_685f0_row29_col30, #T_685f0_row29_col31, #T_685f0_row30_col29, #T_685f0_row30_col30, #T_685f0_row30_col31, #T_685f0_row31_col29, #T_685f0_row31_col30, #T_685f0_row31_col31, #T_685f0_row32_col32, #T_685f0_row32_col36, #T_685f0_row33_col33, #T_685f0_row33_col34, #T_685f0_row33_col35, #T_685f0_row34_col33, #T_685f0_row34_col34, #T_685f0_row34_col35, #T_685f0_row35_col33, #T_685f0_row35_col34, #T_685f0_row35_col35, #T_685f0_row36_col32, #T_685f0_row36_col36, #T_685f0_row37_col37, #T_685f0_row37_col41, #T_685f0_row38_col38, #T_685f0_row38_col39, #T_685f0_row38_col40, #T_685f0_row39_col38, #T_685f0_row39_col39, #T_685f0_row39_col40, #T_685f0_row40_col38, #T_685f0_row40_col39, #T_685f0_row40_col40, #T_685f0_row41_col37, #T_685f0_row41_col41, #T_685f0_row42_col42, #T_685f0_row42_col46, #T_685f0_row43_col43, #T_685f0_row43_col44, #T_685f0_row43_col45, #T_685f0_row44_col43, #T_685f0_row44_col44, #T_685f0_row44_col45, #T_685f0_row45_col43, #T_685f0_row45_col44, #T_685f0_row45_col45, #T_685f0_row46_col42, #T_685f0_row46_col46, #T_685f0_row47_col47, #T_685f0_row48_col48, #T_685f0_row49_col49, #T_685f0_row50_col50, #T_685f0_row51_col51, #T_685f0_row52_col52, #T_685f0_row53_col53, #T_685f0_row54_col54, #T_685f0_row55_col55, #T_685f0_row56_col56, #T_685f0_row57_col57, #T_685f0_row58_col58, #T_685f0_row59_col59, #T_685f0_row60_col60, #T_685f0_row61_col61, #T_685f0_row62_col62, #T_685f0_row63_col63, #T_685f0_row64_col64, #T_685f0_row65_col65, #T_685f0_row66_col66, #T_685f0_row67_col67, #T_685f0_row68_col68, #T_685f0_row69_col69, #T_685f0_row70_col70, #T_685f0_row71_col71, #T_685f0_row72_col72, #T_685f0_row73_col73, #T_685f0_row74_col74, #T_685f0_row75_col75, #T_685f0_row76_col76, #T_685f0_row77_col77, #T_685f0_row78_col78, #T_685f0_row79_col79, #T_685f0_row80_col80, #T_685f0_row81_col81 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_685f0_row0_col1, #T_685f0_row19_col1, #T_685f0_row50_col1, #T_685f0_row68_col24, #T_685f0_row68_col28, #T_685f0_row69_col76, #T_685f0_row69_col77, #T_685f0_row69_col78, #T_685f0_row69_col79, #T_685f0_row69_col80, #T_685f0_row74_col32, #T_685f0_row74_col36 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_685f0_row0_col2, #T_685f0_row0_col7, #T_685f0_row3_col69, #T_685f0_row5_col51, #T_685f0_row5_col66, #T_685f0_row6_col62, #T_685f0_row14_col7, #T_685f0_row14_col9, #T_685f0_row14_col56, #T_685f0_row32_col37, #T_685f0_row32_col41, #T_685f0_row33_col43, #T_685f0_row33_col44, #T_685f0_row33_col45, #T_685f0_row34_col43, #T_685f0_row34_col44, #T_685f0_row34_col45, #T_685f0_row35_col43, #T_685f0_row35_col44, #T_685f0_row35_col45, #T_685f0_row36_col37, #T_685f0_row36_col41, #T_685f0_row50_col15, #T_685f0_row50_col32, #T_685f0_row50_col36, #T_685f0_row55_col32, #T_685f0_row55_col36, #T_685f0_row55_col37, #T_685f0_row55_col41, #T_685f0_row60_col68, #T_685f0_row63_col56, #T_685f0_row73_col72, #T_685f0_row74_col62, #T_685f0_row81_col21, #T_685f0_row81_col22, #T_685f0_row81_col23, #T_685f0_row81_col55 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_685f0_row0_col3, #T_685f0_row0_col16, #T_685f0_row3_col0, #T_685f0_row3_col4, #T_685f0_row4_col5, #T_685f0_row4_col6, #T_685f0_row4_col9, #T_685f0_row4_col14, #T_685f0_row4_col81, #T_685f0_row14_col1, #T_685f0_row14_col4, #T_685f0_row16_col2, #T_685f0_row16_col33, #T_685f0_row16_col34, #T_685f0_row16_col35, #T_685f0_row16_col37, #T_685f0_row16_col41, #T_685f0_row16_col60, #T_685f0_row17_col18, #T_685f0_row18_col1, #T_685f0_row18_col17, #T_685f0_row19_col32, #T_685f0_row19_col33, #T_685f0_row19_col34, #T_685f0_row19_col35, #T_685f0_row19_col36, #T_685f0_row20_col13, #T_685f0_row20_col59, #T_685f0_row20_col61, #T_685f0_row48_col38, #T_685f0_row48_col39, #T_685f0_row48_col40, #T_685f0_row48_col42, #T_685f0_row48_col43, #T_685f0_row48_col44, #T_685f0_row48_col45, #T_685f0_row48_col46, #T_685f0_row56_col76, #T_685f0_row56_col77, #T_685f0_row56_col78, #T_685f0_row56_col79, #T_685f0_row56_col80, #T_685f0_row61_col19, #T_685f0_row61_col20, #T_685f0_row61_col65, #T_685f0_row75_col21, #T_685f0_row75_col22, #T_685f0_row75_col23, #T_685f0_row75_col24, #T_685f0_row75_col25, #T_685f0_row75_col26, #T_685f0_row75_col27, #T_685f0_row75_col28, #T_685f0_row75_col29, #T_685f0_row75_col30, #T_685f0_row75_col31, #T_685f0_row76_col1, #T_685f0_row76_col7, #T_685f0_row76_col8, #T_685f0_row76_col10, #T_685f0_row76_col11, #T_685f0_row76_col12, #T_685f0_row76_col15, #T_685f0_row76_col47, #T_685f0_row76_col48, #T_685f0_row76_col49, #T_685f0_row76_col50, #T_685f0_row76_col51, #T_685f0_row76_col52, #T_685f0_row76_col53, #T_685f0_row76_col54, #T_685f0_row76_col55, #T_685f0_row76_col56, #T_685f0_row76_col57, #T_685f0_row76_col58, #T_685f0_row76_col62, #T_685f0_row76_col63, #T_685f0_row76_col64, #T_685f0_row76_col66, #T_685f0_row76_col67, #T_685f0_row76_col68, #T_685f0_row76_col69, #T_685f0_row76_col70, #T_685f0_row76_col71, #T_685f0_row76_col72, #T_685f0_row76_col73, #T_685f0_row76_col74, #T_685f0_row76_col75, #T_685f0_row77_col1, #T_685f0_row77_col7, #T_685f0_row77_col8, #T_685f0_row77_col10, #T_685f0_row77_col11, #T_685f0_row77_col12, #T_685f0_row77_col15, #T_685f0_row77_col47, #T_685f0_row77_col48, #T_685f0_row77_col49, #T_685f0_row77_col50, #T_685f0_row77_col51, #T_685f0_row77_col52, #T_685f0_row77_col53, #T_685f0_row77_col54, #T_685f0_row77_col55, #T_685f0_row77_col56, #T_685f0_row77_col57, #T_685f0_row77_col58, #T_685f0_row77_col62, #T_685f0_row77_col63, #T_685f0_row77_col64, #T_685f0_row77_col66, #T_685f0_row77_col67, #T_685f0_row77_col68, #T_685f0_row77_col69, #T_685f0_row77_col70, #T_685f0_row77_col71, #T_685f0_row77_col72, #T_685f0_row77_col73, #T_685f0_row77_col74, #T_685f0_row77_col75, #T_685f0_row78_col7, #T_685f0_row78_col8, #T_685f0_row78_col10, #T_685f0_row78_col11, #T_685f0_row78_col12, #T_685f0_row78_col15, #T_685f0_row78_col47, #T_685f0_row78_col49, #T_685f0_row78_col50, #T_685f0_row78_col52, #T_685f0_row78_col55, #T_685f0_row78_col56, #T_685f0_row78_col57, #T_685f0_row78_col58, #T_685f0_row78_col62, #T_685f0_row78_col63, #T_685f0_row78_col64, #T_685f0_row78_col67, #T_685f0_row78_col68, #T_685f0_row78_col69, #T_685f0_row78_col71, #T_685f0_row78_col72, #T_685f0_row78_col73, #T_685f0_row78_col74, #T_685f0_row78_col75, #T_685f0_row79_col7, #T_685f0_row79_col8, #T_685f0_row79_col10, #T_685f0_row79_col11, #T_685f0_row79_col12, #T_685f0_row79_col15, #T_685f0_row79_col47, #T_685f0_row79_col48, #T_685f0_row79_col49, #T_685f0_row79_col50, #T_685f0_row79_col51, #T_685f0_row79_col52, #T_685f0_row79_col53, #T_685f0_row79_col54, #T_685f0_row79_col55, #T_685f0_row79_col56, #T_685f0_row79_col57, #T_685f0_row79_col58, #T_685f0_row79_col62, #T_685f0_row79_col64, #T_685f0_row79_col66, #T_685f0_row79_col67, #T_685f0_row79_col68, #T_685f0_row79_col69, #T_685f0_row79_col71, #T_685f0_row79_col73, #T_685f0_row79_col74, #T_685f0_row79_col75, #T_685f0_row80_col1, #T_685f0_row80_col7, #T_685f0_row80_col8, #T_685f0_row80_col10, #T_685f0_row80_col11, #T_685f0_row80_col12, #T_685f0_row80_col15, #T_685f0_row80_col47, #T_685f0_row80_col48, #T_685f0_row80_col49, #T_685 ...

# %% [markdown]
# # Ejercicio 1:
#
# 1. Qué puede discutir sobre las correlaciones cálculadas?
#
# 2. Cuáles son los atributos que presentan una relación lineal más fuerte con la variable de salida?

# %% [markdown]
# *Solución*
#
# 1. Existen varios grupos de variables que estan correlacionadas entre sí, como overall con el potential, o el conjunto de habilidades como pases o tiro. Así como las diferentes habilidades de portero. Esto tiene sentido ya que es normal que si un jugadores portero, todas sus caracteristicas de portero sean altas, y si no lo es todas serán bajas. A la vez que los jugadores buenos en algunas caracteristicas como pases, tenderan a ser buenos en las demás (dado el overall).
#
# 2. Los atributos mas relacionados linealmente con la varible de salida son el valor del jugador en el mercado, el salario actual del jugador, y la reputacion internacional del jugador.

# %% [markdown]
# # Ejercicio 2:
#
# Sobre los datos preprocesados de entrenamiento presente las gráficas de histograma, dispersión (scatter matrix) y diagramas de caja para la salida y al menos tres atirbutos de entrada, teniendo en cuenta: i) datos preprocesados, ii) datos preprocesados más StandardScaler, iii) datos preprocesados más MinMaxScaler.
#
# **Nota**: se presentan algunas líneas de código de ayuda.

# %% [markdown]
# 20-24,28-31,37-46

# %%
Xtrain_pre.columns #atributos disponibles
# Out:
# Index(['Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value', 'Wage',
#        'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %% [markdown]
# *Se modificaron los atributos a visualizar.
# Usando los que se definieron como los más relacionados con la variable de salida*

# %%
Xm =pd.DataFrame(Xtrain_pre[['Value','Wage','International Reputation']],columns=['Value','Wage','International Reputation'])#definir pandas con atributos seleccionados
Xm['Output'] = ytrain_num #agregar salida

Xtrain_pre2 = Xtrain_pre.copy()
Xtrain_pre2['output'] = ytrain_num
corr_matrix2 = Xm.corr()#matriz de correlación
corr_matrix2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e3399_row0_col0, #T_e3399_row1_col1, #T_e3399_row2_col2, #T_e3399_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e3399_row0_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_e3399_row0_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_e3399_row0_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_e3399_row1_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_e3399_row1_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e3399_row1_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_e3399_row2_col0, #T_e3399_row2_col1, #T_e3399_row2_col3, #T_e3399_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e3399_row3_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_e3399_row3_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# </style>
# <table id="T_e3399" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3399_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_e3399_level0_col1" class="col_heading level0 col1" >Wage</th>
#       <th id="T_e3399_level0_col2" class="col_heading level0 col2" >International Reputation</th>
#       <th id="T_e3399_level0_col3" class="col_heading level0 col3" >Output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3399_level0_row0" class="row_heading level0 row0" >Value</th>
#       <td id="T_e3399_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e3399_row0_col1" class="data row0 col1" >0.863406</td>
#       <td id="T_e3399_row0_col2" class="data row0 col2" >0.651746</td>
#       <td id="T_e3399_row0_col3" class="data row0 col3" >0.976877</td>
#     </tr>
#     <tr>
#       <th id="T_e3399_level0_row1" class="row_heading level0 row1" >Wage</th>
#       <td id="T_e3399_row1_col0" class="data row1 col0" >0.863406</td>
#       <td id="T_e3399_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e3399_row1_col2" class="data row1 col2" >0.662369</td>
#       <td id="T_e3399_row1_col3" class="data row1 col3" >0.836735</td>
#     </tr>
#     <tr>
#       <th id="T_e3399_level0_row2" class="row_heading level0 row2" >International Reputation</th>
#       <td id="T_e3399_row2_col0" class="data row2 col0" >0.651746</td>
#       <td id="T_e3399_row2_col1" class="data row2 col1" >0.662369</td>
#       <td id="T_e3399_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e3399_row2_col3" class="data row2 col3" >0.622339</td>
#     </tr>
#     <tr>
#       <th id="T_e3399_level0_row3" class="row_heading level0 row3" >Output</th>
#       <td id="T_e3399_row3_col0" class="data row3 col0" >0.976877</td>
#       <td id="T_e3399_row3_col1" class="data row3 col1" >0.836735</td>
#       <td id="T_e3399_row3_col2" class="data row3 col2" >0.622339</td>
#       <td id="T_e3399_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
abs(corr_matrix2["Output"]).sort_values(ascending=False)
# Out:
# Output                      1.000000
# Value                       0.976877
# Wage                        0.836735
# International Reputation    0.622339
# Name: Output, dtype: float64

# %%
from pandas.plotting import scatter_matrix

Xm.boxplot()#grafica de caja
plt.show()
scatter_matrix(Xm, figsize=(12, 8)) #scatter con histogramas
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
#scaler = StandardScaler()
scaler = MinMaxScaler()

Xm_pre_sca = pd.DataFrame(scaler.fit_transform(Xm),columns=Xm.columns)
Xm_pre_sca.boxplot()#grafica de caja
plt.show()
scatter_matrix(Xm_pre_sca, figsize=(12, 8)) #scatter con histogramas
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#scaler = MinMaxScaler()

Xm_pre_sca = pd.DataFrame(scaler.fit_transform(Xm),columns=Xm.columns)
Xm_pre_sca.boxplot()#grafica de caja
plt.show()
scatter_matrix(Xm_pre_sca, figsize=(12, 8)) #scatter con histogramas
plt.tight_layout()
plt.show()

# %% [markdown]
# # Se define pipeline para entrenar un modelo de regresión
#
# **Nota:** Se sugiere utilizar un preproceso de normalización tipo StandardScaler o MinMaxScaler para evitar problemas de escala a la hora de identificar los patrones de interés.

# %% [markdown]
# A continuación se genera pipeline completo inlcuyendo preproceso custom, standardscaler y modelo de regresión lineal por mínimos cuadrados.

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
steps = [('preproceso',mypre_fifa(col_euro=col_euro,col_stats=col_stats,cat_usr = cat_usr)),
         ('scaler', StandardScaler()),
         ('regresion',LinearRegression())
         ]
metodo_full = Pipeline(steps=steps)
metodo_full.fit(Xtrain,ytrain_num) #entrena todos los pasos
# Out:
# Pipeline(steps=[('preproceso',
#                  mypre_fifa(cat_usr={'Body Type': ['Normal', 'Lean', 'Stocky',
#                                                    'Messi', 'C. Ronaldo',
#                                                    'Neymar', 'Courtois',
#                                                    'PLAYER_BODY_TYPE_25',
#                                                    'Shaqiri', 'Akinfenwa'],
#                                      'Club': ['FC Barcelona', 'Valencia CF',
#                                               'Fortuna Düsseldorf',
#                                               'Cardiff City', 'Rayo Vallecano',
#                                               'CD Leganés', 'Frosinone',
#                                               'Newcastle United', 'Southampton',
#                                               'Burnley', 'Eintracht Frankfurt',
#                                               'Wolve...
#                                      'Work Rate': ['Medium/ Medium',
#                                                    'High/ Medium',
#                                                    'Medium/ High', 'High/ High',
#                                                    'Medium/ Low', 'High/ Low',
#                                                    'Low/ Medium', 'Low/ High',
#                                                    'Low/ Low']},
#                             col_euro=['Value', 'Wage'],
#                             col_stats=['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF',
#                                        'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#                                        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM',
#                                        'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB',
#                                        'RB'])),
#                 ('scaler', StandardScaler()),
#                 ('regresion', LinearRegression())])

# %%
ytest_e = metodo_full.predict(Xtest) #se evalua el desempeño en el conjunto de test

# %% [markdown]
# Se grafican salida original y las predicciones

# %%
plt.plot(ytest_num,label='original')
plt.plot(ytest_e,'r',label='estimado')

plt.legend()
plt.show()

# %%
plt.scatter(ytest_num,ytest_e)
plt.xlabel('ytest')
plt.ylabel('ytest_e')
plt.show()

# %% [markdown]
# # Ejercicio 3
#
# 1. Utilizando el método steps del pipeline, realice una gráfica de las cargas (pesos) del modelo lineal entrenado. Qué puede discutir al respecto?
#
# 2. Consulte y presente el modelo y problema de optimización de los siguientes regresores:
#
#  - [LinearRegresor](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
#  - [Lasso](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html)
#  - [ElasticNet](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html)
#  - [KernelRidge](https://scikit-learn.org/stable/modules/generated/sklearn.kernel_ridge.KernelRidge.html)
#  - [SGDRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDRegressor.html)
#  - [BayesianRidge](https://scikit-learn.org/stable/modules/linear_model.html#bayesian-ridge-regression)
#  - [Gaussian Process Regressor](https://scikit-learn.org/stable/modules/generated/sklearn.gaussian_process.GaussianProcessRegressor.html)
#
# 3. Utilizando un esquema de validación cruzada de 5 folds sobre el conjunto de entrenamiento preprocesado, compare el rendimiento en el conjunto de test de los regresores del punto 2. fijando el score del [gridsearch](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) en términos del error absoluto medio y el error cuádratico medio. Justifique los hiperparámetros a buscar y la rejilla de valores escogida para cada algoritmo según los modelos estudiados en clase y las respuestas del punto 2. Para el caso del kernelRidge y GPR se sugiere trabajar sobre un conjunto de train de 5000 puntos para evitar problemas de memoría en los cálculos de la matriz kernel (presente los resultados para kernel ridge utilizando una función rbf).

# %% [markdown]
# **Revisar el cuaderno lado a lado sklearn para ver como definir el pipeline**

# %%
metodo_full.steps[2][1].coef_.shape
# Out:
# (81,)

# %%
#Ayuda punto 1:
#el pipeline contiene el método steps codificando los elementos del proceso.
#En este caso el regresor esta en la posición 2 y en la 1 de la tupla arrojada
#Revisando la documentación de LinearRegression, el atributo coef_ contiene las cargas del modelo
plt.stem(abs(metodo_full.steps[2][1].coef_))
plt.xlabel('atributo')
plt.ylabel('$w_j$')
plt.show()

# %% [markdown]
# *De la grafica de los pesos, se ve que los pesos 20-24,28-31,37-46 son los más importantes para el regresor al momento de hacer las predicciones.*
# *Estos pesos coinciden con los atributos de las caracteristicas de los jugadores como la altrura, el peso, la finalización o la finalizacion de cabeza*

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.gaussian_process import GaussianProcessRegressor
#Ayuda punto 2 y 3
#Dado que el preproceso no cambia, se sugiera generar el pipeline sin mypre_fifa para ahorrar tiempo
steps = [('scaler', StandardScaler()), #ajustar según ejercicio
         ('regresion',Lasso()) #ajustar según ejercicio
         ]
metodo_gs = Pipeline(steps=steps) #pipeline a utilizar en el gridsearch
#Recuerde realizar el fit del gridsearch sobre las matrices de entrada y vector de salida preprocesados
#Xtrain_pre ytrain_num
metodo_gs.fit(Xtrain_pre,ytrain_num) #entrena todos los pasos
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('regresion', Lasso())])

# %%
#Dado que el preproceso no cambia, se sugiera generar el pipeline sin mypre_fifa para ahorrar tiempo
steps = [('scaler', StandardScaler()), #ajustar según ejercicio
         ('regresion',ElasticNet()) #ajustar según ejercicio
         ]
metodo_gs = Pipeline(steps=steps) #pipeline a utilizar en el gridsearch
#Recuerde realizar el fit del gridsearch sobre las matrices de entrada y vector de salida preprocesados
#Xtrain_pre ytrain_num
metodo_gs.fit(Xtrain_pre,ytrain_num) #entrena todos los pasos

# %%
#Dado que el preproceso no cambia, se sugiera generar el pipeline sin mypre_fifa para ahorrar tiempo
steps = [('scaler', StandardScaler()), #ajustar según ejercicio
         ('regresion',KernelRidge()) #ajustar según ejercicio
         ]
metodo_gs = Pipeline(steps=steps) #pipeline a utilizar en el gridsearch
#Recuerde realizar el fit del gridsearch sobre las matrices de entrada y vector de salida preprocesados
#Xtrain_pre ytrain_num
metodo_gs.fit(Xtrain_pre,ytrain_num) #entrena todos los pasos

# %%
#Dado que el preproceso no cambia, se sugiera generar el pipeline sin mypre_fifa para ahorrar tiempo
steps = [('scaler', StandardScaler()), #ajustar según ejercicio
         ('regresion',SGDRegressor()) #ajustar según ejercicio
         ]
metodo_gs = Pipeline(steps=steps) #pipeline a utilizar en el gridsearch
#Recuerde realizar el fit del gridsearch sobre las matrices de entrada y vector de salida preprocesados
#Xtrain_pre ytrain_num
metodo_gs.fit(Xtrain_pre,ytrain_num) #entrena todos los pasos

# %%
#Dado que el preproceso no cambia, se sugiera generar el pipeline sin mypre_fifa para ahorrar tiempo
steps = [('scaler', StandardScaler()), #ajustar según ejercicio
         ('regresion',BayesianRidge()) #ajustar según ejercicio
         ]
metodo_gs = Pipeline(steps=steps) #pipeline a utilizar en el gridsearch
#Recuerde realizar el fit del gridsearch sobre las matrices de entrada y vector de salida preprocesados
#Xtrain_pre ytrain_num
metodo_gs.fit(Xtrain_pre,ytrain_num) #entrena todos los pasos

# %%
#Dado que el preproceso no cambia, se sugiera generar el pipeline sin mypre_fifa para ahorrar tiempo
steps = [('scaler', StandardScaler()), #ajustar según ejercicio
         ('regresion',GaussianProcessRegressor()) #ajustar según ejercicio
         ]
metodo_gs = Pipeline(steps=steps) #pipeline a utilizar en el gridsearch
#Recuerde realizar el fit del gridsearch sobre las matrices de entrada y vector de salida preprocesados
#Xtrain_pre ytrain_num
metodo_gs.fit(Xtrain_pre,ytrain_num) #entrena todos los pasos
